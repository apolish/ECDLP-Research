# %% [markdown]
# **Preparing the dataset for work**

# %%
# !cp -r /kaggle/input/ecdlp-research/* /kaggle/working/
# !ls -lah /kaggle/working/
# Out:
# total 40K
# drwxr-xr-x 3 root root 4.0K Dec 15 15:00 .
# drwxr-xr-x 5 root root 4.0K Dec 15 14:58 ..
# -rw-r--r-- 1 root root 5.5K Dec 15 15:00 generate_data.py
# -rw-r--r-- 1 root root  18K Dec 15 15:00 secp256k1.py
# drwxr-xr-x 2 root root 4.0K Dec 15 14:58 .virtual_documents

# %% [markdown]
# **Generating data (keys and statistics)**

# %%
# !python /kaggle/working/generate_data.py --curve_mode legacy
# Out:
# Processed: 100000/100000 (100.0%)
# Done. Data: /kaggle/working/key_list_data_20251215150040.csv | Stats: /kaggle/working/key_list_stats_20251215150040.txt
