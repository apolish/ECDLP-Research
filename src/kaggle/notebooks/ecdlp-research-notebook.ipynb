# %% [markdown]
# **Preparing the dataset for work**

# %%
# !cp -r /kaggle/input/d/<USER_NAME>/ecdlp-research/* /kaggle/working/
# !ls -lah /kaggle/working/
# Out:
# total 40K
# drwxr-xr-x 3 root root 4.0K Jan 31 19:16 .
# drwxr-xr-x 5 root root 4.0K Jan 31 19:15 ..
# -rw-r--r-- 1 root root 5.1K Jan 31 19:16 generate_data.py
# -rw-r--r-- 1 root root  20K Jan 31 19:16 secp256k1.py
# drwxr-xr-x 2 root root 4.0K Jan 31 19:16 .virtual_documents

# %% [markdown]
# **Generating data (keys and statistics)**

# %%
# !python /kaggle/working/generate_data.py --curve_mode test --total_keys 1_000_000
# Out:
# Processed: 1000000/1000000 (100.0%)
# Done. Data: /kaggle/working/key_list_data_20260131191633.csv | Stats: /kaggle/working/key_list_stats_20260131191633.txt

# %%
# !python /kaggle/working/generate_data.py --curve_mode legacy --total_keys 100_000
# Out:
# Processed: 100000/100000 (100.0%)
# Done. Data: /kaggle/working/key_list_data_20260131191955.csv | Stats: /kaggle/working/key_list_stats_20260131191955.txt
